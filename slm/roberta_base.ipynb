# %% [markdown]
# <a href="https://colab.research.google.com/github/nirb28/llm/blob/main/slm/flan5.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print("HI")
from transformers import AutoModelForCausalLM, AutoTokenizer

model = AutoModelForCausalLM.from_pretrained("FacebookAI/roberta-base", cache_dir="./rb_cache")
tokenizer = AutoTokenizer.from_pretrained("FacebookAI/roberta-base", cache_dir="./rb_cache")

#inputs = tokenizer("A step by step recipe to make bolognese pasta:", return_tensors="pt")
#outputs = model.generate(**inputs)
#print(tokenizer.batch_decode(outputs, skip_special_tokens=True))
# Out:
# HI
# model.safetensors:   0%|          | 0.00/499M [00:00<?, ?B/s]
# If you want to use `RobertaLMHeadModel` as a standalone, add `is_decoder=True.`
# tokenizer_config.json:   0%|          | 0.00/25.0 [00:00<?, ?B/s]
# vocab.json:   0%|          | 0.00/899k [00:00<?, ?B/s]
# merges.txt:   0%|          | 0.00/456k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/1.36M [00:00<?, ?B/s]

# %%
# Load from local cache
from transformers import AutoModelForCausalLM, AutoTokenizer

model = AutoModelForCausalLM.from_pretrained(
    f"D:/ds/work/workspace/git/my_model_repo/models/roberta-base")
tokenizer = AutoTokenizer.from_pretrained(
    f"D:/ds/work/workspace/git/my_model_repo/models/roberta-base")

inputs = tokenizer("A step by step recipe to make bolognese pasta:", return_tensors="pt")
outputs = model.generate(**inputs)
print(tokenizer.batch_decode(outputs, skip_special_tokens=True))
# Out:
# If you want to use `RobertaLMHeadModel` as a standalone, add `is_decoder=True.`
# C:\Users\dalje\.conda\envs\llm-dev-env\Lib\site-packages\transformers\generation\utils.py:1259: UserWarning: Using the model-agnostic default `max_length` (=20) to control the generation length. We recommend setting `max_new_tokens` to control the maximum length of the generation.
#   warnings.warn(
# ['A step by step recipe to make bolognese pasta:']

# %%
from adapters import AutoAdapterModel
from transformers import AutoTokenizer
model = AutoAdapterModel.from_pretrained("./models/flan_t5/models--google--flan-t5-small/snapshots/0fc9ddf78a1e988dac52e2dac162b0ede4fd74ab")
tokenizer = AutoTokenizer.from_pretrained("./models/flan_t5/models--google--flan-t5-small/snapshots/0fc9ddf78a1e988dac52e2dac162b0ede4fd74ab")
# Out:
# <>:3: SyntaxWarning: invalid escape sequence '\d'
# <>:3: SyntaxWarning: invalid escape sequence '\d'
# C:\Users\dalje\AppData\Local\Temp\ipykernel_23628\2351638494.py:3: SyntaxWarning: invalid escape sequence '\d'
#   model = AutoAdapterModel.from_pretrained(f"D:\ds\work\workspace\git\my_model_repo\models\roberta-base")
# C:\Users\dalje\AppData\Local\Temp\ipykernel_23628\2351638494.py:3: SyntaxWarning: invalid escape sequence '\d'
#   model = AutoAdapterModel.from_pretrained(f"D:\ds\work\workspace\git\my_model_repo\models\roberta-base")
# ---------------------------------------------------------------------------
# HFValidationError                         Traceback (most recent call last)
# ...

# %%
#adapter_name = model.load_adapter("nbogdan/flant5-small-2ex-overall-1epochs")
adapter_name = model.load_adapter("./models/flan_t5/adapters/flant5-small-2ex-overall-1epochs")
model.set_active_adapters(adapter_name)
inputs = tokenizer("translate English to German: How old are you?", return_tensors="pt")
outputs = model.generate(**inputs)
print(tokenizer.batch_decode(outputs, skip_special_tokens=True))
# Out:
# Overwriting existing head 'flant5-small-2ex-overall-1epochs'
# ['Wie sind Sie?']

# %%
model.delete_adapter(adapter_name)
inputs = tokenizer("translate English to German: How old are you?", return_tensors="pt")
outputs = model.generate(**inputs)
print(tokenizer.batch_decode(outputs, skip_special_tokens=True))
# Out:
# ['Wie ich er bitten?']
